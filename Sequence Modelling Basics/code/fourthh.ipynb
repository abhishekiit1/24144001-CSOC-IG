# %%
# Notebook 4: RNN Model Training and Evaluation

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import numpy as np

# Use your dataset and dataloader from Notebook 3
# Assuming 'dataloader' variable exists from Notebook 3

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the RNN model class
class SimpleRNN(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_layers=1):
        super(SimpleRNN, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.rnn = nn.RNN(embed_dim, hidden_dim, batch_first=True, num_layers=num_layers)
        self.fc = nn.Linear(hidden_dim, 1)


    def forward(self, x):
        embedded = self.embedding(x)                      # (B, L, E)
        out, hidden = self.rnn(embedded)                  # out: (B, L, H), hidden: (1, B, H)
        last_hidden = hidden[-1]                          # (B, H)
        logits = self.fc(last_hidden)                     # (B, 1)
        return logits.squeeze(1)                          # (B,)



# Hyperparameters
VOCAB_SIZE = len(word2idx)  # from Notebook 3
EMBED_DIM = 128
HIDDEN_DIM = 256
NUM_LAYERS = 1
LR = 0.02
EPOCHS = 5

# Initialize model, loss, optimizer
model = SimpleRNN(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM, NUM_LAYERS).to(device)
criterion = nn.BCEWithLogitsLoss()  # expects raw logits from model
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)


lengths = [len(seq[seq != 0]) for seq, _ in dataloader.dataset]
print(f"Average sequence length (non-padded): {np.mean(lengths):.2f}")

# Training loop
for epoch in range(1, EPOCHS + 1):
    model.train()
    epoch_loss = 0
    epoch_acc = 0
    total = 0
    
    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)                     # raw logits
        loss = criterion(outputs, labels)
        loss.backward()

        # ✅ Inspect gradients of first trainable parameter
        for name, param in model.named_parameters():
            if param.requires_grad and param.grad is not None:
                print(f"{name}: grad mean = {param.grad.mean():.6f}, grad std = {param.grad.std():.6f}")
                break  # only inspect one param per batch

        optimizer.step()
        
        epoch_loss += loss.item() * inputs.size(0)
        probs = torch.sigmoid(outputs)
        preds = (probs >= 0.5).float()
        epoch_acc += (preds == labels).sum().item()
        total += inputs.size(0)
    
    print(f"Epoch {epoch}/{EPOCHS} - Loss: {epoch_loss/total:.4f} - Accuracy: {epoch_acc/total:.4f}")


# Save model checkpoint
torch.save(model.state_dict(), "rnn_model.pth")
print("Model saved as rnn_model.pth")

# Evaluation on training data (for demonstration)
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        preds = (outputs >= 0.5).float()
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

from sklearn.metrics import classification_report, confusion_matrix

print("Classification Report:")
print(classification_report(all_labels, all_preds))

print("Confusion Matrix:")
print(confusion_matrix(all_labels, all_preds))
# Out:
# Using device: cuda
# Average sequence length (non-padded): 73.87
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000006
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000001
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000001
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000001
# embedding.weight: grad mean = -0.000000, grad std = 0.000001
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000001
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000001
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000001
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000006
# embedding.weight: grad mean = -0.000000, grad std = 0.000004
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = 0.000000, grad std = 0.000014
# embedding.weight: grad mean = -0.000000, grad std = 0.000007
# embedding.weight: grad mean = 0.000000, grad std = 0.000012
# embedding.weight: grad mean = -0.000000, grad std = 0.000009
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000009
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000007
# embedding.weight: grad mean = 0.000000, grad std = 0.000030
# embedding.weight: grad mean = 0.000000, grad std = 0.000014
# embedding.weight: grad mean = 0.000000, grad std = 0.000013
# embedding.weight: grad mean = -0.000000, grad std = 0.000008
# embedding.weight: grad mean = -0.000000, grad std = 0.000006
# embedding.weight: grad mean = 0.000000, grad std = 0.000009
# embedding.weight: grad mean = 0.000000, grad std = 0.000008
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000016
# embedding.weight: grad mean = -0.000000, grad std = 0.000021
# embedding.weight: grad mean = 0.000000, grad std = 0.000030
# embedding.weight: grad mean = 0.000000, grad std = 0.000024
# embedding.weight: grad mean = 0.000000, grad std = 0.000015
# embedding.weight: grad mean = -0.000000, grad std = 0.000010
# embedding.weight: grad mean = 0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000006
# embedding.weight: grad mean = -0.000000, grad std = 0.000038
# embedding.weight: grad mean = 0.000000, grad std = 0.000010
# embedding.weight: grad mean = -0.000000, grad std = 0.000009
# embedding.weight: grad mean = -0.000000, grad std = 0.000008
# embedding.weight: grad mean = 0.000000, grad std = 0.000017
# embedding.weight: grad mean = 0.000000, grad std = 0.000011
# embedding.weight: grad mean = 0.000000, grad std = 0.000007
# embedding.weight: grad mean = 0.000000, grad std = 0.000010
# embedding.weight: grad mean = -0.000000, grad std = 0.000007
# embedding.weight: grad mean = 0.000000, grad std = 0.000009
# embedding.weight: grad mean = 0.000000, grad std = 0.000030
# embedding.weight: grad mean = 0.000000, grad std = 0.000016
# embedding.weight: grad mean = -0.000000, grad std = 0.000016
# embedding.weight: grad mean = 0.000000, grad std = 0.000028
# embedding.weight: grad mean = 0.000000, grad std = 0.000011
# embedding.weight: grad mean = -0.000000, grad std = 0.000020
# embedding.weight: grad mean = 0.000000, grad std = 0.000006
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = -0.000000, grad std = 0.000006
# embedding.weight: grad mean = 0.000000, grad std = 0.000009
# embedding.weight: grad mean = -0.000000, grad std = 0.000011
# embedding.weight: grad mean = 0.000000, grad std = 0.000011
# embedding.weight: grad mean = 0.000000, grad std = 0.000046
# embedding.weight: grad mean = 0.000000, grad std = 0.000012
# embedding.weight: grad mean = -0.000000, grad std = 0.000016
# embedding.weight: grad mean = -0.000000, grad std = 0.000009
# embedding.weight: grad mean = 0.000000, grad std = 0.000014
# embedding.weight: grad mean = 0.000000, grad std = 0.000004
# embedding.weight: grad mean = -0.000000, grad std = 0.000009
# embedding.weight: grad mean = -0.000000, grad std = 0.000008
# embedding.weight: grad mean = 0.000000, grad std = 0.000011
# embedding.weight: grad mean = 0.000000, grad std = 0.000011
# embedding.weight: grad mean = -0.000000, grad std = 0.000024
# embedding.weight: grad mean = 0.000000, grad std = 0.000078
# embedding.weight: grad mean = 0.000000, grad std = 0.000009
# embedding.weight: grad mean = 0.000000, grad std = 0.000008
# embedding.weight: grad mean = 0.000000, grad std = 0.000009
# embedding.weight: grad mean = -0.000000, grad std = 0.000010
# embedding.weight: grad mean = -0.000000, grad std = 0.000015
# embedding.weight: grad mean = -0.000000, grad std = 0.000021
# embedding.weight: grad mean = 0.000000, grad std = 0.000022
# embedding.weight: grad mean = -0.000000, grad std = 0.000008
# embedding.weight: grad mean = 0.000000, grad std = 0.000008
# embedding.weight: grad mean = -0.000000, grad std = 0.000026
# embedding.weight: grad mean = 0.000000, grad std = 0.000010
# embedding.weight: grad mean = 0.000000, grad std = 0.000009
# embedding.weight: grad mean = 0.000000, grad std = 0.000067
# embedding.weight: grad mean = 0.000000, grad std = 0.000010
# embedding.weight: grad mean = 0.000000, grad std = 0.000003
# embedding.weight: grad mean = -0.000000, grad std = 0.000005
# embedding.weight: grad mean = 0.000000, grad std = 0.000015
# embedding.weight: grad mean = -0.000000, grad std = 0.000010
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = 0.000000, grad std = 0.000002
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000015
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000011
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000038
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = -0.000000, grad std = 0.000000
# embedding.weight: grad mean = 0.000000, grad std = 0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 65
#      63 outputs = model(inputs)                     # raw logits
#      64 loss = criterion(outputs, labels)
# ---> 65 loss.backward()
#      67 # ✅ Inspect gradients of first trainable parameter
#      68 for name, param in model.named_parameters():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(df['polarity'].value_counts())  # Should be roughly equal
print(df['polarity'].unique())        # Should be only 0 and 1
# Out:
# polarity
# 0    50000
# 1    50000
# Name: count, dtype: int64
# [0 1]
